# %% [markdown]
# # Выпускная работа

# %% [markdown]
# По вариантам выдается задание из Часть 1  - для базовой группы (целевая группа 1). Продвинутой группе (целевая группа 2) выдается по 1 заданию из каждой части

# %% [markdown]
# # Часть первая: Работа с данным для анализа и прогнозирования
#
# Перед Вами - датасет с сырыми данными. Необходимо провести аналитическую работу с датасетом, выявить артефакты и сделать выводы по полученным данным. Используйте различные инструменты отображения данных: таблицы, графики, функции.
# Обязательно после каждого шага - должен быть вывод, а в коде - комментарии.

# %% [markdown]
# ## План работы**:**
# - Открыть файл с данными, изучить общую информацию, описать полученный датасет
# - Провести предобработку данных (проверка на пропуски, дубли, типы данных в столбцах)
# - Провести исследовательский анализ данных, построить графики;
# - Далее, в зависимости от набора данных необходимо реализовать модель решающую одну( можно несколько) задач ИИ, рекомендации по применению набора данных к решению задач:
#
#     **Задача прогнозирования для набора данных:** 3.	Данные отказов оборудования в компании, 4.	Данные энергопотребления на нескольких участках, 8.	Данные выработка солнечных батарей,
#
#     **Задача регрессии для набора данных:** 1.	Данные трудоустройства в ИТ, 2.	Данные датчиков качества воздуха на производстве, 6.	Данные прочности бетона, 7.	Данные газовых датчиков с разными измеряемыми газами, 8.	Данные выработка солнечных батарей, 9.	Данные качества воды, 10.	Данные о производственном процессе
#
#     **Задача классификации для набора данных:** 1.	Данные трудоустройства в ИТ, 2.	Данные датчиков качества воздуха на производстве, 4.	Данные энергопотребления на нескольких участках, 5.	Данные неисправностей электрических машин, 6.	Данные прочности бетона, 7.	Данные газовых датчиков с разными измеряемыми газами, 8.	Данные выработка солнечных батарей, 9.	Данные качества воды, 10.	Данные о производственном процессе
# - Проанализировать датасет и описать выводы;

# %% [markdown]
# ### 1. Откройте файл с данными и изучите общую информацию.

# %%
Импортируем необходимые библиотеки

# %%
Загружаем датасет

# %%
Выводим общую инфо
Размер дата сета
первые 5 строк
типы данных
описание числовых признаков

# %% [markdown]
# ### Вывод

# %% [markdown]
# ### 2. Предобработка данных

# %%
Проверка на пропуски

# %%
Проверка на дубликаты

# %%
Проверка на аномалии(например отрицательные значения, взависимости от данных)

# %% [markdown]
# ### Вывод

# %% [markdown]
# ### 3. Исследовательский анализ данных.

# %% [markdown]
# ### Вывод

# %% [markdown]
# ### 4. Решение задачи ИИ

# %% [markdown]
# Перед Вами - датасет с данными. Необходимо провести аналитическую работу с датасетом, изучить тренды и тенденции, построить прогнозную модель и сделать выводы по полученным данным. Используйте различные инструменты отображения данных: таблицы, графики, функции.
# Обязательно после каждого шага - должен быть вывод, а в коде - комментарии.

# %% [markdown]
# ________________________________________________________________________________

# %% [markdown]
# ### 5. Общий вывод

# %% [markdown]
# # Часть вторая: Работа с изображениями, распознавание и классификация
#
# Перед Вами — набор изображений и соответствующих меток. Необходимо провести работу по подготовке данных, исследованию датасета и построению модели для распознавания и классификации объектов. Используйте библиотеки OpenCV, PIL, matplotlib, pandas и scikit-learn или TensorFlow/Keras и другие изученные библиотеки. Обязательно после каждого шага делайте вывод, а в коде — комментарии.
# Список тем:
# 1. Построение модели для автоматической сортировки фруктов по виду
# 2. Разработка модели для автоматического распознавания и подсчета кубических объектов на конвейерной ленте
# 3. Разработка модели для обнаружения и классификации дефектов на печатных платах
# 4. Разработка модели классификация электронных компонентов
# 5. Разработка модели обнаружение признаков пожароопасной ситуации
# 6. Разработка модели распознавания дефектных автомобильной резины
# 7. Создание модели для классификации типов дефектов на поверхности металлических изделий
# 8. Создание модели для контроля качества бисквитов по признакам пересушивания, трещин и деформации формы
# 9. Создание модели классификации бытовых отходов
# 10. Создание модели контроля качества изделий на производстве

# %% [markdown]
# ## План работы**:**
# 1. Загрузить изображения и метки, изучить общую структуру датасета
# 2. Провести предварительную обработку изображений (изменение размера, нормализация, проверка баланса классов)
# 3. Провести исследовательский анализ: визуализировать изображения, оценить разнообразие, размеры, качество
# 4. Подготовить данные для обучения модели (разделение на train/test, кодирование меток)
# 5. Построить и обучить модель классификации изображений
# 6. Оценить качество модели, сделать выводы и рекомендации по применению

# %% [markdown]
# ### 1. Загрузка и изучение датасета

# %%
# Загрузите библиотеки: os, pandas, matplotlib, PIL
# Укажите путь к папке с изображениями и файлу с метками (например, CSV)
# Загрузите таблицу с метками (если есть) или организуйте список изображений и меток
# Выведите общую информацию: количество изображений, количество классов, примеры меток

# %% [markdown]
# Опишите, что представляет собой датасет: сколько изображений, сколько классов, какие объекты изображены, как организованы данные (папки, CSV-файл). Укажите, сбалансированы ли классы.

# %% [markdown]
# ### 2. Предварительная обработка изображений

# %%
# Пример: изменение размера всех изображений до 224x224
# Нормализация пикселей (деление на 255)
# Проверка на битые или пустые изображения
# Визуализация нескольких изображений из разных классов
# Анализ распределения классов (гистограмма)

# %% [markdown]
# Какие преобразования были выполнены? Каково распределение классов? Есть ли дисбаланс? Все ли изображения пригодны для обучения?

# %% [markdown]
# ### 3. Исследовательский анализ данных (EDA)

# %%
# Постройте сетку изображений (например, 3x3) с подписями классов
# Оцените разнообразие: освещение, ракурсы, фон
# Проверьте, есть ли шум, размытость, артефакты сжатия
# При необходимости — преобразуйте цветовое пространство (в grayscale, HSV и т.д.)

# %% [markdown]
# Опишите визуальные особенности датасета. Насколько однородны изображения одного класса? Какие сложности могут возникнуть при обучении модели (например, сложный фон, малый размер объекта)?

# %% [markdown]
# ### Вывод

# %% [markdown]
# ### 4. Подготовка данных для обучения

# %%
# Разделите данные на обучающую и тестовую выборки (80/20)
# Закодируйте метки (LabelEncoder или to_categorical)
# При необходимости — выполните аугментацию (повороты, отражения)
# Сформируйте массивы X (изображения) и y (метки)

# %% [markdown]
# Какие шаги были выполнены для подготовки данных? Была ли применена аугментация? Почему да или нет?

# %% [markdown]
# ### 5.  Построение и обучение модели

# %%
# Вариант 1 (базовый): Используйте простую модель на основе Fully Connected слоев (после Flatten)
# Вариант 2 (продвинутый): Используйте CNN (Conv2D, MaxPooling, Dropout, Dense)
# Скомпилируйте модель (выберите оптимизатор, функцию потерь, метрику)
# Обучите модель на 10–20 эпохах
# Постройте графики потерь и accuracy

# %% [markdown]
# Какая архитектура была выбрана? Как быстро сходилась модель? Была ли переобучение? Какие метрики достигнуты?

# %% [markdown]
# ### 6. Оценка и выводы

# %%
# Сделайте предсказания на тестовой выборке
# Постройте confusion matrix
# Выведите classification report (precision, recall, F1)
# Визуализируйте несколько тестовых изображений с предсказанными и истинными метками

# %% [markdown]
# Насколько хорошо модель справляется с задачей? Какие классы она распознаёт лучше, а какие — хуже? Где можно применить такую модель в промышленности (например, контроль качества, автоматическая сортировка)? Какие улучшения можно внести?
